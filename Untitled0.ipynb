# %%
import numpy as np
import skimage.transform
import sklearn.cross_validation
import pickle
import os
import matplotlib.pyplot as plt
import cPickle 
# %matplotlib inline

# %%
f = file('data_Salicon_T_img.cPickle', 'rb')
loaded_obj = cPickle.load(f)
f.close()
X,y = loaded_obj

# %%
 plt.imshow(X[1].transpose(1,2,0))

# %%
 plt.imshow(y[1].transpose(1,2,0).reshape(224,224))

# %%
np.amax(y[1])
# Out:
# 1.0

# %%
np.amin(y[1])
# Out:
# -1.0
